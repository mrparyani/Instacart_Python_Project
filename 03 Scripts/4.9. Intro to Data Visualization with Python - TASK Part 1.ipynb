# %% [markdown]
# # 4.9. Intro to Data Visualization with Python - TASK Part 1

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import Data
path = r'C:\Users\eminc\OneDrive\A  - Career Foundry\Data Immersion\A4 Python Fundamentals for Data Analysts\01-2023 Instacart Basket Analysis'

# %%
df_new_customer = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %%
# T1: Download the customer data set and add it to your “Original Data” folder. - Done
# T2: Create a new notebook in your “Scripts” folder for part 1 of this task.  - Done
# T3: Import your analysis libraries, as well as your new customer data set as a dataframe. - Done

# %%
# Checking the Data

# %%
df_new_customer.shape
# Out:
# (206209, 10)

# %%
df_new_customer.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# T4: Wrangle the data so that it follows consistent logic; 
#    for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.

# %%
df_new_customer.rename(columns = {'First Name': 'first_name'}, inplace = True)
df_new_customer.rename(columns = {'Last Name': 'last_name'}, inplace = True)
df_new_customer.rename(columns = {'Gender': 'gender'}, inplace = True)
df_new_customer.rename(columns = {'STATE': 'state'}, inplace = True)
df_new_customer.rename(columns = {'Age': 'age'}, inplace = True)

# %%
df_new_customer.head()
# Out:
#    user_id first_name    Surnam  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df1_new_customer = df_new_customer

# %%
df1_new_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   first_name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   gender        206209 non-null  object
#  4   state         206209 non-null  object
#  5   age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
df1_new_customer.head()
# Out:
#    user_id first_name    Surnam  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# T5: Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement;
#     for example, check for and address missing values and duplicates, and convert any mixed-type data.

# %%
df1_new_customer.describe()
# Out:
#              user_id            age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
# Converting user_id from int64 data to string data
df1_new_customer['user_id'] = df1_new_customer['user_id'].astype('str')

# %%
df1_new_customer['user_id'].dtype
# Out:
# dtype('O')

# %%
df1_new_customer.describe()
# Out:
#                  age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000
# mean       49.501646       1.499823   94632.852548
# std        18.480962       1.118433   42473.786988
# min        18.000000       0.000000   25903.000000
# 25%        33.000000       0.000000   59874.000000
# 50%        49.000000       1.000000   93547.000000
# 75%        66.000000       3.000000  124244.000000
# max        81.000000       3.000000  593901.000000

# %%
df1_new_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  object
#  1   first_name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   gender        206209 non-null  object
#  4   state         206209 non-null  object
#  5   age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 15.7+ MB

# %%
# Checking all columns for mixed-type data
for col in df1_new_customer.columns.tolist():
  weird = (df1_new_customer[[col]].applymap(type) != df1_new_customer[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_new_customer[weird]) > 0:
    print (col)
# Out:
# first_name

# %%
# Column "first_name" contains mixed-type data and converting to string type ("0" or "object")
df1_new_customer['first_name'] = df1_new_customer['first_name'].astype('str')

# %%
df1_new_customer['first_name'].dtype
# Out:
# dtype('O')

# %%
# Finding missing values
df1_new_customer.isnull().sum()
# Out:
# user_id         0
# first_name      0
# Surnam          0
# gender          0
# state           0
# age             0
# date_joined     0
# n_dependants    0
# fam_status      0
# income          0
# dtype: int64

# %%
# No missing values found

# %%
df1_new_customer.shape
# Out:
# (206209, 10)

# %%
# Checking for duplicates
df1_dups = df1_new_customer[df1_new_customer.duplicated()]

# %%
df1_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, Surnam, gender, state, age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
# No duplicates found

# %%
df_ords_prods_cust = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_customer-behavior.pkl'))

# %%
df_ords_prods_cust.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#    ...    price_range_loc     busiest day    busiest days  \
# ...

# %%
df_ords_prods_cust.rename(columns = {'_merge': '_merge_old'}, inplace = True)

# %%
df_ords_prods_cust.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   _merge_old  ...    price_range_loc     busiest day    busiest days  \
# ...

# %%
df1_new_customer.head()
# Out:
#   user_id first_name    Surnam  gender       state  age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df1_new_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  object
#  1   first_name    206209 non-null  object
#  2   Surnam        206209 non-null  object
#  3   gender        206209 non-null  object
#  4   state         206209 non-null  object
#  5   age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 15.7+ MB

# %%
df_ords_prods_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
#  9   _merge_old              category
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  price_range_loc         object
#  15  busiest day             object
#  16  busiest days            object
#  17  busiest_period_of_day   object
#  18  max_order               int64
#  19  loyalty_flag            object
#  20  avg_spending            float64
# ...

# %%
df_ords_prods_cust['user_id'] = df_ords_prods_cust['user_id'].astype('str')

# %%
df_ords_prods_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 object
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
#  9   _merge_old              category
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  price_range_loc         object
#  15  busiest day             object
#  16  busiest days            object
#  17  busiest_period_of_day   object
#  18  max_order               int64
#  19  loyalty_flag            object
#  20  avg_spending            float64
# ...

# %%
df_ords_prods_cust_newcust_merged = df_ords_prods_cust.merge(df1_new_customer, on = 'user_id', indicator = True)

# %%
df_ords_prods_cust_newcust_merged.head()
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   _merge_old  ... first_name  Surnam  gender    state age date_joined  \
# ...

# %%
df_ords_prods_cust_newcust_merged.rename(columns = {'Surnam': 'last_name'}, inplace = True)

# %%
df_ords_prods_cust_newcust_merged.head()
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   _merge_old  ... first_name  last_name  gender    state age date_joined  \
# ...

# %%
df2 = df_ords_prods_cust_newcust_merged.drop(columns = ['_merge_old'])

# %%
df2.head()
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  first_name  last_name  gender    state age date_joined  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 33 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 object
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
#  9   product_name            object
#  10  aisle_id                int64
#  11  department_id           int64
#  12  prices                  float64
#  13  price_range_loc         object
#  14  busiest day             object
#  15  busiest days            object
#  16  busiest_period_of_day   object
#  17  max_order               int64
#  18  loyalty_flag            object
#  19  avg_spending            float64
#  20  spending_flag           object
# ...

# %%
     df2.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'instacart_clean_data.pkl'))
